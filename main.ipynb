# %%
import requests
from bs4 import BeautifulSoup
import json
import sys

from variables import default_headers

# %%
url_search = "https://www.hiswa.nl/bedrijven/hiswa-erkende-bedrijven/"

# %%
response = requests.get(
        url_search, headers=default_headers)

# %%
response.text
# Out:
# '<!doctype html>\n<html class="no-js" lang="nl">\n<head>\n\t\n    <meta charset="utf-8">\n    <meta http-equiv="x-ua-compatible" content="ie=edge">\n\n\t<script src="/addthemes/hiswasite/assets/foundationXY/js/vendor/jquery.js"></script>\n\t<script src="/addthemes/hiswasite/assets/foundationXY/js/vendor/what-input.js"></script>\n  \t<script src="/addthemes/hiswasite/assets/foundationXY/js/vendor/foundation.min.js"></script>\n\n\n\n<title>Alle HISWA erkende bedrijven op een rij</title>\n<meta name="description" content="Vind een bootverhuur, zeilschool, vaaropleiding, jachthaven, watersportwinkel, importeur, makelaar of transportbedrijf bij jou in de buurt!" />\n<meta property="og:title" content="Alle HISWA erkende bedrijven op een rij" />\n<meta property="og:type" content="Website" />\n<meta property="og:description" content="Vind een HISWA bedrijf bij jou in de buurt" />\n<meta property="og:url" content="https://www.hiswa.nl/bedrijven/hiswa-erkende-bedrijven" />\n<meta property="og:
# ...
